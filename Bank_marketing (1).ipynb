# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-675a742c-30a2-4299-b472-191963e989e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-675a742c-30a2-4299-b472-191963e989e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('bank-full.csv',sep=';')

# %%
data.shape
# Out:
# (45211, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
data['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['job'].value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# Name: count, dtype: int64

# %%
data.replace(to_replace='unknown',value=np.nan,inplace=True)

# %%
data['job'].isnull().sum()
# Out:
# np.int64(288)

# %%
data['education'].isnull().sum()
# Out:
# np.int64(1857)

# %%
data['contact'].isnull().sum()
# Out:
# np.int64(13020)

# %%
data['poutcome'].value_counts()
# Out:
# poutcome
# failure    4901
# other      1840
# success    1511
# Name: count, dtype: int64

# %%
data['y'].value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
data['job'].fillna('blue-collar',inplace=True)
# Out:
# /tmp/ipykernel_1728/2738397064.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['job'].fillna('blue-collar',inplace=True)

# %%
data['job'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['education'].value_counts()
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# Name: count, dtype: int64

# %%
data['education'].fillna('secondary',inplace=True)
# Out:
# /tmp/ipykernel_1728/2938913135.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['education'].fillna('secondary',inplace=True)

# %%
data['education'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['contact'].value_counts()
# Out:
# contact
# cellular     29285
# telephone     2906
# Name: count, dtype: int64

# %%
data['contact'].fillna('cellular',inplace=True)
# Out:
# /tmp/ipykernel_1728/2956100804.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['contact'].fillna('cellular',inplace=True)

# %%
data['contact'].isnull().sum()
# Out:
# np.int64(0)

# %%
data.drop('poutcome',axis=1,inplace=True)

# %%
data.groupby('y')['age'].mean()
# Out:
# y
# no     40.838986
# yes    41.670070
# Name: age, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=data,x='education')
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
len(data)
# Out:
# 45211

# %%
data.groupby('education').agg({'y': 'count'})
# Out:
#                y
# education
# primary     6851
# secondary  25059
# tertiary   13301

# %%
data['y'].value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
39922+5289

# %%
sns.barplot(data=data, x='y',hue='education')
# Out:
# <Axes: xlabel='y'>

# %%
sns.barplot(y='y',x='education',data=data)
plt.show()

# %%
data['y']=data['y'].map({'yes' : 1,'no':0})

# %%
data['y']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45206    1
# 45207    1
# 45208    1
# 45209    0
# 45210    0
# Name: y, Length: 45211, dtype: int64

# %%
sns.barplot(data=data,x='marital',y='y')
plt.show()

# %%
sns.countplot(data=data,x='marital',hue='y')
# Out:
# <Axes: xlabel='marital', ylabel='count'>

# %%
fig,ax=plt.subplots(figsize=(10,5))
sns.countplot(data=data,x='job',hue='y')
ax.tick_params(axis='x',rotation=90)

# %%
sns.countplot(data=data,x='housing',hue='y')
# Out:
# <Axes: xlabel='housing', ylabel='count'>

# %%
sns.countplot(data=data,x='month',hue='y')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
sns.countplot(data=data,x='loan',hue='y')
# Out:
# <Axes: xlabel='loan', ylabel='count'>

# %%
fig,ax=plt.subplots(figsize=(14,6))
sns.countplot(data=data,x='campaign',hue='y')
ax.tick_params(axis='x',rotation=90)

# %%
data['campaign'].value_counts().sort_index()
# Out:
# campaign
# 1     17544
# 2     12505
# 3      5521
# 4      3522
# 5      1764
# 6      1291
# 7       735
# 8       540
# 9       327
# 10      266
# 11      201
# 12      155
# 13      133
# 14       93
# 15       84
# 16       79
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 23       22
# 24       20
# 25       22
# 26       13
# 27       10
# 28       16
# 29       16
# 30        8
# 31       12
# 32        9
# 33        6
# 34        5
# 35        4
# 36        4
# 37        2
# 38        3
# 39        1
# 41        2
# 43        3
# 44        1
# 46        1
# 50        2
# 51        1
# 55        1
# 58        1
# 63        1
# Name: count, dtype: int64

# %%
sns.barplot(data=data,x='y',y='balance')
# Out:
# <Axes: xlabel='y', ylabel='balance'>

# %%
sns.barplot(data=data,x='y',y='age')
# Out:
# <Axes: xlabel='y', ylabel='age'>

# %%
sns.barplot(data=data,x='y',y='duration')
# Out:
# <Axes: xlabel='y', ylabel='duration'>

# %%
sns.barplot(data=data,x='y',y='previous')
# Out:
# <Axes: xlabel='y', ylabel='previous'>

# %%
sns.barplot(data=data,x='y',y='pdays')
# Out:
# <Axes: xlabel='y', ylabel='pdays'>

# %%
sns.barplot(data=data,x='y',y=data['pdays'].replace(-1,0))
# Out:
# <Axes: xlabel='y', ylabel='pdays'>

# %%
previously_contacted=data[~(data['pdays']==-1)] #customers who have been previously contacted

# %%
sns.barplot(data=previously_contacted,x='y',y='pdays')
# Out:
# <Axes: xlabel='y', ylabel='pdays'>

# %%
sns.countplot(data=data,x='default',hue='y')
# Out:
# <Axes: xlabel='default', ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler,OrdinalEncoder # scaling numeric column,encoding categorical column
from sklearn.compose import make_column_selector # to select numeric and categoric columns
from sklearn.compose import ColumnTransformer #to transform columns using appropriate scaling / encoding

# %%
target_column='y'
features=data.drop(columns=target_column)
target=data[target_column]

# %%
from pandas.core.arrays import categorical
numeric_selector=make_column_selector(dtype_include='number')
categorical_selector=make_column_selector(dtype_exclude='number')

# %%
numeric_columns=numeric_selector(features)
numeric_columns
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
categorical_columns=categorical_selector(features)
categorical_columns
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month']

# %%
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married  secondary      no     1506     yes   no
# 4   33   blue-collar   single  secondary      no        1      no   no
#
#     contact  day month  duration  campaign  pdays  previous  y
# 0  cellular    5   may       261         1     -1         0  0
# 1  cellular    5   may       151         1     -1         0  0
# 2  cellular    5   may        76         1     -1         0  0
# 3  cellular    5   may        92         1     -1         0  0
# 4  cellular    5   may       198         1     -1         0  0

# %% [markdown]
# ## train test split

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=45,stratify=target)

# %%
data['y'].value_counts(normalize=True)
# Out:
# y
# 0    0.883015
# 1    0.116985
# Name: proportion, dtype: float64

# %%
len(X_train)==len(y_train) # verify X and y have same length)
# Out:
# True

# %%
len(X_test)==len(y_test)
# Out:
# True

# %%
y_train.value_counts(normalize=True)
# Out:
# y
# 0    0.883018
# 1    0.116982
# Name: proportion, dtype: float64

# %% [markdown]
# ##preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler,OrdinalEncoder # scaling numeric column,encoding categorical column

preprocessor=ColumnTransformer([('category',OrdinalEncoder(),categorical_columns),
  ('numbers',MinMaxScaler(),numeric_columns)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('category', OrdinalEncoder(),
#                                  ['job', 'marital', 'education', 'default',
#                                   'housing', 'loan', 'contact', 'month']),
#                                 ('numbers', MinMaxScaler(),
#                                  ['age', 'balance', 'day', 'duration',
#                                   'campaign', 'pdays', 'previous'])])

# %%
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier

model=Pipeline([
    ('preprocess',preprocessor),
    ('dt_class',DecisionTreeClassifier())
])

model
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('category', OrdinalEncoder(),
#                                                   ['job', 'marital',
#                                                    'education', 'default',
#                                                    'housing', 'loan', 'contact',
#                                                    'month']),
#                                                  ('numbers', MinMaxScaler(),
#                                                   ['age', 'balance', 'day',
#                                                    'duration', 'campaign',
#                                                    'pdays', 'previous'])])),
#                 ('dt_class', DecisionTreeClassifier())])

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# hyper parameters are parameters that are set before training .for example in decision tree max_depth,min_samples_split are hyperparameters. in practice,its hard to find optimal values for these parameters before training the model. the optimal values are found out by grid search cross-validation approach

# %%
from sklearn.model_selection import GridSearchCV

param_grid ={'dt_class__max_depth':[2,4,3,5,7,9],
             'dt_class__min_samples_split':[5,10,20,30,40],
             'dt_class__min_samples_leaf':[10,20,30,40,50],
             'dt_class__criterion':['gini','entropy'],
             'dt_class__class_weight':[{0:1,1:5},{0:1,1:1}],

             }# dt_class__ ---->to know preprocessor or dt_class ,it pass through the pipeline

# %%
grid_search=GridSearchCV(model,param_grid,cv=5,refit=True)

# %%
grid_search.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1728/3078958945.py in <cell line: 0>()
# ----> 1 grid_search.fit(X_train,y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
#    1026             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
# ...

# %% [markdown]
# ## TRAIN PERFORMANCE

# %%
from sklearn.metrics import balanced_accuracy_score,precision_score,recall_score

best_model=grid_search.best_estimator_
y_train_pred=best_model.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1728/2419429894.py in <cell line: 0>()
#       1 from sklearn.metrics import balanced_accuracy_score,precision_score,recall_score
#       2
# ----> 3 best_model=grid_search.best_estimator_
#       4 y_train_pred=best_model.predict(X_train)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
balanced_accuracy=balanced_accuracy_score(y_train,y_train_pred)
precision=precision_score(y_train,y_train_pred,pos_label=1)
recall=recall_score(y_train,y_train_pred)

# %%
print(balanced_accuracy)

# %%
print(precision)

# %%
print(recall)

# %% [markdown]
# ## TEST PERFORMANCE

# %%
data['y'].value_counts(normalize=True)

# %%
best_model.named_steps['dt_class'].get_depth()

# %%
best_model.named_steps['dt_class'].get_n_leaves()

# %%
y_test_pred=best_model.predict(X_test)

# %%
balanced_accuracy_t=balanced_accuracy_score(y_test,y_test_pred)
precision_t=precision_score(y_test,y_test_pred,pos_label=1)
recall_t=recall_score(y_test,y_test_pred)

# %%
print(balanced_accuracy_t)
print(precision_t)
print(recall_t)

# %% [markdown]
# BAGGING AND RANDOM FOREST

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import BaggingClassifier

# %%
model=Pipeline([
    ('preprocess',preprocessor),
    ('bc_class',BaggingClassifier())])

model
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('category', OrdinalEncoder(),
#                                                   ['job', 'marital',
#                                                    'education', 'default',
#                                                    'housing', 'loan', 'contact',
#                                                    'month']),
#                                                  ('numbers', MinMaxScaler(),
#                                                   ['age', 'balance', 'day',
#                                                    'duration', 'campaign',
#                                                    'pdays', 'previous'])])),
#                 ('bc_class', BaggingClassifier())])

# %%
param_grid ={
            'bc_class__estimator':[DecisionTreeClassifier()],
            'bc_class__n_estimators':[10,20,30],
             'bc_class__max_samples':[100,200],
             'bc_class__max_features':[10,20,50],
              'bc_class__estimator__max_depth':[5,7],
             'bc_class__estimator__min_samples_leaf':[10,20,30],
             'bc_class__estimator__class_weight':[{0:1,1:5},{0:1,1:1}],

             }

# %%
grid_search=GridSearchCV(model,param_grid,cv=5,refit=True)

# %%
grid_search.fit(X_train,y_train)
